# %% [markdown]
# This notebook is used to inspect the .vis.npz file contents ensuring a correct UV table

# %%
import numpy as np

# Load the .npz file
data = np.load('D:/exoALMA_disk_data/data/DM_Tau_time_ave_continuum.vis.npz')

# List all arrays stored in the file
print(data.files)

# Inspect each array
for key in data.files:
    print(f"{key}: shape={data[key].shape}, dtype={data[key].dtype}")
    print(f"First few values: {data[key].flat[:10]}")
# Out:
# ['u', 'v', 'Vis', 'Wgt']
# u: shape=(2026203,), dtype=float64
# First few values: [ -8023.80526797   7598.04808136 -20364.61899259  10493.72628065
#    3006.83550292  -8664.06077986 -22138.09885307  15621.84920987
#  -12340.82971978  18517.52603757]
# v: shape=(2026203,), dtype=float64
# First few values: [  4799.30282935   4741.85091331 -13614.32450561  -6901.92302748
#  -17948.05129464  -3118.3413243    1069.60584254    -57.43938315
#  -18413.62627341 -11701.21914986]
# Vis: shape=(2026203,), dtype=complex128
# First few values: [ 0.5002068 -0.05948756j  0.15892117+0.00621363j  0.07513604-0.39169029j
#  -0.24244221-0.06074422j -0.05857161-0.21683147j -0.04277314+0.14733488j
#   0.11096615-0.06986545j  0.14155969-0.35706027j  0.3529806 -0.24854928j
#   0.02673244+0.08733256j]
# Wgt: shape=(2026203,), dtype=float64
# First few values: [37.5972538  42.24213028 41.46541214 37.49946022 39.41573906 49.2173996
#  42.99600601 36.49872017 36.10210991 32.64205742]

# %%
F_cpd = np.arange(0.25, 0.00, -0.01)  
print(F_cpd)
# Out:
# [0.25 0.24 0.23 0.22 0.21 0.2  0.19 0.18 0.17 0.16 0.15 0.14 0.13 0.12
#  0.11 0.1  0.09 0.08 0.07 0.06 0.05 0.04 0.03 0.02 0.01]
