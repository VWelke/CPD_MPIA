# %% [markdown]
# # The slurm scripts

# %% [markdown]
# Note:
#
# 1. The .slurm and.py files are different for each gap and disk
# 2. So maybe I should run core for each , each job sumission runs 10 cores  for 10 flux levels
#  - to do that maybe need a for loop for each step , but how to make sure that uses several cores not one?
# 3. Submit 3 jobs for 3 gaps once at a time
# 4. Check
# 5. Add some printing statements

# %% [markdown]
# Problem 1: I want to run one core for each flux bin's injection-recovery, yet for the inject_loop.py, i looped over the flux levels , so If i used one core to run that py script, the injections will happen one by one. Also even if i turned the file back to one flux bin, how to assign the cores to each trial of injection and have them run simulataneously, quite many layers in here.
#
# Solution
